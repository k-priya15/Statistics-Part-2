# %% [markdown]
# #Statistics Part 2 Assignment

# %% [markdown]
# ##Statistics Part 2 Questions

# %% [markdown]
# 1. What is hypothesis testing in statistics?
#
# - Hypothesis testing is a statistical method used to make decisions or inferences about a population parameter based on sample data. It involves testing an assumption (hypothesis) to determine its validity using observed data.

# %% [markdown]
# ---

# %% [markdown]
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# - Null Hypothesis (H₀): A default assumption that there is no effect or no difference.
#
#  Alternative Hypothesis (H₁ or Ha): Suggests that there is an effect or a difference.
#
#  They are mutually exclusive; if one is true, the other must be false.

# %% [markdown]
# ---

# %% [markdown]
# 3. What is the significance level in hypothesis testing, and why is it important?
#
# The significance level (α) is the probability of rejecting the null hypothesis when it is actually true. Common values are 0.05 or 0.01. It helps control the risk of making a Type I error.

# %% [markdown]
# ---

# %% [markdown]
# 4. What does a P-value represent in hypothesis testing?
#
# The P-value is the probability of obtaining a result equal to or more extreme than the observed data, assuming the null hypothesis is true. It helps assess the strength of evidence against the null hypothesis.

# %% [markdown]
# ---

# %% [markdown]
# 5. How do you interpret the P-value in hypothesis testing?
#
# If P-value ≤ α: Reject the null hypothesis (strong evidence against it).
#
# If P-value > α: Fail to reject the null hypothesis (not enough evidence).

# %% [markdown]
# ---

# %% [markdown]
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#
# Type I Error (False Positive): Rejecting the null hypothesis when it's true.
#
# Type II Error (False Negative): Failing to reject the null hypothesis when it's false.

# %% [markdown]
# ---

# %% [markdown]
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
# One-tailed Test: Tests for effect in one specific direction (greater than or less than).
#
# Two-tailed Test: Tests for any difference (either direction).

# %% [markdown]
# ---

# %% [markdown]
# 8. What is the Z-test, and when is it used in hypothesis testing?
#
# The Z-test is used to compare sample and population means when the population standard deviation is known and the sample size is large (typically n > 30).

# %% [markdown]
# ---

# %% [markdown]
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
# Z = (X̄ - μ) / (σ / √n)
# Where:
#
# X̄ = sample mean,
#
# μ = population mean,
#
# σ = population standard deviation,
#
# n = sample size.
# It shows how many standard deviations the sample mean is from the population mean.

# %% [markdown]
# ---

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#
# The T-distribution is used when the population standard deviation is unknown and the sample size is small (n < 30). It's similar to the normal distribution but has heavier tails.

# %% [markdown]
# ---

# %% [markdown]
# 11. What is the difference between a Z-test and a T-test?
#
# Z-test: Used when population standard deviation is known and sample size is large.
#
# T-test: Used when population standard deviation is unknown and sample size is small.

# %% [markdown]
# ---

# %% [markdown]
# 12. What is the T-test, and how is it used in hypothesis testing?
#
# The T-test assesses whether the means of two groups are statistically different from each other. Common types include one-sample, independent two-sample, and paired sample T-tests.

# %% [markdown]
# ---

# %% [markdown]
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#
# Both tests compare sample data to population data or another sample. The Z-test is used for large samples or known σ, while the T-test is used for small samples or unknown σ. As sample size increases, the T-distribution approaches the Z-distribution.

# %% [markdown]
# ---

# %% [markdown]
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#
# A confidence interval gives a range of values within which the true population parameter is likely to fall. It reflects the precision and reliability of the estimate.

# %% [markdown]
# ---

# %% [markdown]
# 15. What is the margin of error, and how does it affect the confidence interval?
#
# The margin of error defines how much the estimate can vary. A larger margin leads to a wider confidence interval, indicating less precision. It depends on the standard error and confidence level.

# %% [markdown]
# ---

# %% [markdown]
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#
# Bayes' Theorem is used to update the probability of a hypothesis based on new evidence. It's important in fields like medical testing, machine learning, and decision-making.

# %% [markdown]
# ---

# %% [markdown]
# 17. What is the Chi-square distribution, and when is it used?
#
# The Chi-square distribution is used in hypothesis testing for categorical data, especially in tests of independence and goodness of fit. It only takes positive values and is skewed right.

# %% [markdown]
# ---

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#
# It checks whether observed frequencies match expected frequencies for a categorical variable.
# Steps:
#
# Set hypotheses,
#
# Compute expected frequencies,
#
# Calculate test statistic,
#
# Compare with Chi-square distribution.

# %% [markdown]
# ---

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#
# The F-distribution is used to compare two variances or in ANOVA tests. It’s always positive and right-skewed. Used when testing equality of multiple means.

# %% [markdown]
# ---

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions?
#
# ANOVA (Analysis of Variance) compares means of three or more groups.
# Assumptions:
#
# Independent samples,
#
# Normally distributed data,
#
# Equal variances across groups.

# %% [markdown]
# ---

# %% [markdown]
# 21. What are the different types of ANOVA tests?
#
# One-Way ANOVA: One independent variable.
#
# Two-Way ANOVA: Two independent variables.
#
# Repeated Measures ANOVA: Same subjects tested multiple times.

# %% [markdown]
# ---

# %% [markdown]
# 22. What is the F-test, and how does it relate to hypothesis testing?
#
# The F-test is used to compare two variances or in ANOVA to test for differences among group means. It evaluates if the ratio of variances is significantly different from 1.

# %% [markdown]
# ---

# %% [markdown]
# ##Practical Questions

# %%
#Q1) Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.
from scipy.stats import norm
import numpy as np

sample = [102, 98, 100, 105, 99]
pop_mean = 100
pop_std = 5
n = len(sample)
sample_mean = np.mean(sample)

z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z)))

print("Z-score:", z)
print("P-value:", p_value)
# Out:
# Z-score: 0.3577708763999651
# P-value: 0.7205147871362563

# %%
#Q2)  Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.
import numpy as np
from scipy.stats import norm

data = np.random.normal(loc=52, scale=5, size=30)
pop_mean = 50
z = (np.mean(data) - pop_mean) / (5 / np.sqrt(len(data)))
p_value = 2 * (1 - norm.cdf(abs(z)))

print("Z-score:", z)
print("P-value:", p_value)
# Out:
# Z-score: 3.1324748403976272
# P-value: 0.001733392831772651

# %%
#Q3)  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
from scipy.stats import norm
import numpy as np

sample = np.array([45, 47, 50, 52, 48])
pop_mean = 50
pop_std = 4

z = (np.mean(sample) - pop_mean) / (pop_std / np.sqrt(len(sample)))
p = 2 * (1 - norm.cdf(abs(z)))

print("Z-score:", z)
print("P-value:", p)
# Out:
# Z-score: -0.8944271909999167
# P-value: 0.371093369522697

# %%
#Q4) Perform a two-tailed Z-test using Python and visualize the decision region on a plot.
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

z = 1.96
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y)
plt.fill_between(x, y, where=(x <= -z) | (x >= z), color='red', alpha=0.3)
plt.title("Two-tailed Z-test decision region")
plt.axvline(-z, color='red', linestyle='--')
plt.axvline(z, color='red', linestyle='--')
plt.show()

# %%
#Q5) @ Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_type_errors(mu0=0, mu1=1, sigma=1, alpha=0.05):
    x = np.linspace(-4, 4, 1000)
    z_critical = norm.ppf(1 - alpha)

    plt.plot(x, norm.pdf(x, mu0, sigma), label="H0")
    plt.plot(x, norm.pdf(x, mu1, sigma), label="H1")
    plt.axvline(z_critical, color='red', linestyle='--', label='Critical Value')
    plt.fill_between(x, norm.pdf(x, mu0, sigma), where=(x >= z_critical), color='red', alpha=0.3, label='Type I Error')
    plt.fill_between(x, norm.pdf(x, mu1, sigma), where=(x < z_critical), color='blue', alpha=0.3, label='Type II Error')
    plt.legend()
    plt.title("Type I and Type II Errors")
    plt.show()

plot_type_errors()

# %%
#Q6) Write a Python program to perform an independent T-test and interpret the results.
from scipy.stats import ttest_ind

group1 = [25, 30, 28, 35, 40]
group2 = [20, 22, 27, 33, 36]

t_stat, p = ttest_ind(group1, group2)
print("T-statistic:", t_stat)
print("P-value:", p)
# Out:
# T-statistic: 0.9841356626102459
# P-value: 0.3538725426305123

# %%
#Q7) Perform a paired sample T-test using Python and visualize the comparison results.
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

before = [50, 52, 53, 49, 48]
after = [55, 54, 56, 52, 51]

t_stat, p = ttest_rel(before, after)
print("T-statistic:", t_stat)
print("P-value:", p)

plt.plot(before, label="Before")
plt.plot(after, label="After")
plt.legend()
plt.title("Paired Sample Comparison")
plt.show()
# Out:
# T-statistic: -6.531972647421809
# P-value: 0.0028378459267344464

# %%
#Q8) Simulate data and perform both Z-test and T-test, then compare the results using Python.
import numpy as np
from scipy.stats import norm, ttest_1samp

data = np.random.normal(60, 10, 20)
pop_mean = 55

# Z-test
z = (np.mean(data) - pop_mean) / (10 / np.sqrt(len(data)))
z_p = 2 * (1 - norm.cdf(abs(z)))

# T-test
t_stat, t_p = ttest_1samp(data, pop_mean)

print("Z-test P-value:", z_p)
print("T-test P-value:", t_p)
# Out:
# Z-test P-value: 0.04121352962576119
# T-test P-value: 0.07960479431254755

# %%
#Q9) Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
import numpy as np
from scipy.stats import norm

def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)
    z = norm.ppf((1 + confidence) / 2)
    margin = z * std_err
    return mean - margin, mean + margin

sample = [10, 12, 14, 13, 15]
ci = confidence_interval(sample)
print("Confidence Interval:", ci)
# Out:
# Confidence Interval: (np.float64(11.113975229329755), np.float64(14.486024770670246))

# %%
#Q10) Write a Python program to calculate the margin of error for a given confidence level using sample data.
import numpy as np
from scipy.stats import norm

sample = [50, 52, 53, 51, 54]
confidence = 0.95
n = len(sample)
std_err = np.std(sample, ddof=1) / np.sqrt(n)
z = norm.ppf((1 + confidence) / 2)
moe = z * std_err
print("Margin of Error:", moe)
# Out:
# Margin of Error: 1.385903824349678

# %%
#Q11) D Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.
def bayes_theorem(prior_A, prob_B_given_A, prob_B):
    return (prior_A * prob_B_given_A) / prob_B

result = bayes_theorem(0.01, 0.9, 0.05)
print("Posterior Probability:", result)
# Out:
# Posterior Probability: 0.18000000000000002

# %%
#Q12) Perform a Chi-square test for independence between two categorical variables in Python.
import pandas as pd
from scipy.stats import chi2_contingency

data = [[10, 20], [20, 30]]
stat, p, dof, expected = chi2_contingency(data)
print("Chi-square stat:", stat, "P-value:", p)
# Out:
# Chi-square stat: 0.128 P-value: 0.7205147871362552

# %%
#Q13) Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.
from scipy.stats import chi2_contingency

observed = [[15, 25], [20, 40]]
_, _, _, expected = chi2_contingency(observed)
print("Expected Frequencies:\n", expected)
# Out:
# Expected Frequencies:
#  [[14. 26.]
#  [21. 39.]]

# %%
#Q14) Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
from scipy.stats import chisquare

observed = [20, 30, 50]
expected = [25, 25, 50]
stat, p = chisquare(f_obs=observed, f_exp=expected)
print("Chi-square stat:", stat, "P-value:", p)
# Out:
# Chi-square stat: 2.0 P-value: 0.36787944117144245

# %%
#Q15) Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import chi2

x = np.linspace(0, 20, 1000)
plt.plot(x, chi2.pdf(x, df=4))
plt.title("Chi-square Distribution (df=4)")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.show()

# %%
#Q16) Implement an F-test using Python to compare the variances of two random samples.
import numpy as np

group1 = [10, 12, 14, 16, 18]
group2 = [8, 10, 12, 14, 16]

f = np.var(group1, ddof=1) / np.var(group2, ddof=1)
print("F-statistic:", f)
# Out:
# F-statistic: 1.0

# %%
#Q17) Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results.
from scipy.stats import f_oneway

g1 = [22, 24, 23, 25]
g2 = [20, 21, 19, 18]
g3 = [30, 28, 27, 29]

f_stat, p = f_oneway(g1, g2, g3)
print("F-statistic:", f_stat, "P-value:", p)
# Out:
# F-statistic: 48.800000000000004 P-value: 1.4763314494112792e-05

# %%
#Q18) Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.
import matplotlib.pyplot as plt

groups = [g1, g2, g3]
plt.boxplot(groups)
plt.title("One-Way ANOVA Group Comparison")
plt.xlabel("Groups")
plt.ylabel("Values")
plt.show()

# %%
#Q19) Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.
import scipy.stats as stats

def check_anova_assumptions(data):
    for i, group in enumerate(data):
        print(f"Group {i+1} normality p-value:", stats.shapiro(group).pvalue)
    print("Equal variance p-value (Levene's Test):", stats.levene(*data).pvalue)

check_anova_assumptions([g1, g2, g3])
# Out:
# Group 1 normality p-value: 0.9718770585603881
# Group 2 normality p-value: 0.9718770585603881
# Group 3 normality p-value: 0.9718770585603881
# Equal variance p-value (Levene's Test): 1.0

# %%
#Q20) D Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results.
import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd

df = pd.DataFrame({
    'score': [85, 90, 88, 92, 70, 75, 73, 78],
    'method': ['A', 'A', 'B', 'B', 'A', 'A', 'B', 'B'],
    'gender': ['M', 'F', 'M', 'F', 'M', 'F', 'M', 'F']
})

model = ols('score ~ C(method) + C(gender) + C(method):C(gender)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                       sum_sq   df         F    PR(>F)
# C(method)             15.125  1.0  0.138921  0.728265
# C(gender)             45.125  1.0  0.414466  0.554767
# C(method):C(gender)    0.125  1.0  0.001148  0.974593
# Residual             435.500  4.0       NaN       NaN

# %%
#Q21) Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.
x = np.linspace(0.01, 5, 500)
from scipy.stats import f
plt.plot(x, f.pdf(x, dfn=5, dfd=2))
plt.title("F-distribution (dfn=5, dfd=2)")
plt.xlabel("F value")
plt.ylabel("Density")
plt.show()

# %%
#Q22) Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.
plt.boxplot([g1, g2, g3])
plt.title("Group Means Comparison")
plt.xlabel("Group")
plt.ylabel("Scores")
plt.show()

# %%
#Q23) Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.
data = np.random.normal(50, 10, 30)
t_stat, p = stats.ttest_1samp(data, 50)
print("T-statistic:", t_stat, "P-value:", p)
# Out:
# T-statistic: -2.6384268848551877 P-value: 0.013256372100200144

# %%
#Q24) Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.
data = [10, 12, 14, 15, 13]
sample_var = np.var(data, ddof=1)
n = len(data)
chi_sq = (n - 1) * sample_var / 4
from scipy.stats import chi2
p = 1 - chi2.cdf(chi_sq, df=n-1)
print("Chi-square stat:", chi_sq, "P-value:", p)
# Out:
# Chi-square stat: 3.7 P-value: 0.44812592399383866

# %%
#Q25) Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.
from statsmodels.stats.proportion import proportions_ztest

count = np.array([40, 30])
nobs = np.array([100, 120])
z, p = proportions_ztest(count, nobs)
print("Z-statistic:", z, "P-value:", p)
# Out:
# Z-statistic: 2.378474901516276 P-value: 0.01738442035206615

# %%
#Q26) Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.

import numpy as np
from scipy.stats import f # Import the f distribution

var1 = np.var(g1, ddof=1)
var2 = np.var(g2, ddof=1)
f_statistic = var1 / var2 # Rename to f_statistic
print("F-statistic:", f_statistic)

x = np.linspace(0, 5, 1000)
plt.plot(x, f.pdf(x, dfn=4, dfd=4)) # Use f from scipy.stats
plt.title("F-distribution")
plt.axvline(f_statistic, color='red') # Use f_statistic
plt.show()
# Out:
# F-statistic: 1.0

# %%
#Q27) Perform a Chi-square test for goodness of fit with simulated data and analyze the results.
observed = [18, 22, 20, 40]
expected = [25, 25, 25, 25]
stat, p = chisquare(f_obs=observed, f_exp=expected)
print("Chi-square stat:", stat, "P-value:", p)
# Out:
# Chi-square stat: 12.32 P-value: 0.006363629995195269
